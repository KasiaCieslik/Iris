# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import random

from sklearn import datasets
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import matthews_corrcoef

from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import matthews_corrcoef

from src.data_preprocessing.utils import StringToBinary, ObjectToDataTime, DataFrameSelector, Get_Dummies,SmallerAgeRange
pd.set_option('display.max_rows', 500)
# %matplotlib inline

# %% [markdown]
# ### Read the csv data to df

# %%
df = pd.read_csv('noshowappointments/KaggleV2-May-2016.csv') 
df_copy = df.copy()

# %% [markdown]
# ### Data exploration

# %%
print(f'Dataset has {df.shape[0]} rows and {df.shape[1]} columns')

print(f'We see that one person has more then one appoitment, bacause we have {df.shape[0]} appointments and only {len(df.PatientId.unique())} persons')

len(df.AppointmentID.unique())
print('Appitment ID is unique. For every appoitnment we have new number. We can use this number in index')
# Out:
# Dataset has 110527 rows and 14 columns
# We see that one person has more then one appoitment, bacause we have 110527 appointments and only 62299 persons
# Appitment ID is unique. For every appoitnment we have new number. We can use this number in index

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %%
a = df.PatientId.value_counts()
a.reset_index().PatientId.head(100).plot()

# %% [markdown]
# ### sum appoitments for every patient

# %%
df['sum_appoitments'] = df.groupby('PatientId')['AppointmentID'].transform('count')
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show  sum_appoitments
# 0         0           0        0             0      No                2
# 1         0           0        0             0      No                2
# 2         0           0        0             0      No                2
# 3         0           0        0             0      No                2
# 4         1           0        0             0      No                1

# %%
# age vs sum_appoitment for every person
plt.figure(figsize=(20,15))
plt.scatter(df['Age'],df['sum_appoitments'])

# %% [markdown]
# Age column
# - min is -1 what means that here we have some mistake
# - max value is 115. We can drop all values which are more then 100

# %% [markdown]
# ### sum of appoitments for every age

# %%
plt.figure(figsize=(20,15))
df['sum_app_for_age'] = df.groupby('Age')['sum_appoitments'].transform('sum')
plt.scatter(df['Age'],df['sum_app_for_age'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Check correlation

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr())

# %% [markdown]
# correlation:
# - age & diabates
# - diabetes & hipertension
# - age & hipertension

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age', y ='Diabetes',hue='Gender',data=df,err_style='band')

### the graph shows how many people of a given age are ill in relation to all people of that age

# %%
# percentage of woman with diabetes in group of 60
len(df[(df['Gender']=='F')&(df['Age']==60)&(df['Diabetes']==1)])/len(df[(df['Gender']=='F')&(df['Age']==60)])
# Out:
# 0.1688055281342547

# %%
# percentage of woman with diabetes in group of 20
len(df[(df['Gender']=='F')&(df['Age']==20)&(df['Diabetes']==1)])/len(df[(df['Gender']=='F')&(df['Age']==20)])
# Out:
# 0.28188539741219965

# %%
# how many woman/man of that age has Hipertension
plt.figure(figsize=(20,10))
sns.lineplot(x='Age', y ='Hipertension',hue='Gender',data=df,err_style='band')

# %%
# how many people (woman/men) has problems with alcohol in that age
plt.figure(figsize=(20,10))
sns.lineplot(x='Age', y ='Alcoholism',hue='Gender',data=df,err_style='band')

# %%
df[['Age','Diabetes','Alcoholism','Hipertension']].corr()
# Out:
#                    Age  Diabetes  Alcoholism  Hipertension
# Age           1.000000  0.292391    0.095811      0.504586
# Diabetes      0.292391  1.000000    0.018474      0.433086
# Alcoholism    0.095811  0.018474    1.000000      0.087971
# Hipertension  0.504586  0.433086    0.087971      1.000000

# %% [markdown]
# ### train/test split with unique patient in train /test

# %%
patient_list = df.PatientId.unique()

random.seed(42)
np.random.shuffle(patient_list)



size_of_test = round(len(patient_list)*0.25)
size_of_train = round(len(patient_list)*0.75)

patient_train = patient_list[size_of_test:]
patient_test =  patient_list[:size_of_test]

train = df[df['PatientId'].isin(patient_train)]
test = df[df['PatientId'].isin(patient_test)]

# we check if train and test has unique patientID
np.intersect1d(patient_train,patient_test)
# Out:
# array([], dtype=float64)

# %% [markdown]
# ### categorical pipeline & numerical pipeline

# %%
#categorical pipeline
obj_date_to_dt=['ScheduledDay','AppointmentDay']
cat_pipeline = Pipeline([
    ('StringToBinary',StringToBinary()),
    ('ObjectToDataTime',ObjectToDataTime(obj_date_to_dt)),
    ('GetDummies',Get_Dummies())
])

train1 = cat_pipeline.fit_transform(train)

#numerical pipeline
age_range = ['Age']
pipeline_num = Pipeline([
    ('SmallerAgeRange',SmallerAgeRange(age_range))
])
train_prep = pipeline_num.fit_transform(train1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### corr after pipeline / data preparation

# %%
df_prep_corr = train_prep.corr().abs()

pd.options.display.max_rows = 100
s = df_prep_corr.unstack()
so = s.sort_values(kind="quicksort",ascending=False)
print(pd.DataFrame(so[so<1])[:200].to_string())
# Out:
#                                                                             0
# AppointmentID                     DaysBetween                        0.770184
# DaysBetween                       AppointmentID                      0.770184
# Age                               Hipertension                       0.504577
# Hipertension                      Age                                0.504577
# Diabetes                          Hipertension                       0.425491
# Hipertension                      Diabetes                           0.425491
# DaysBetween                       SMS_received                       0.398785
# SMS_received                      DaysBetween                        0.398785
# Age                               Diabetes                           0.289211
# Diabetes                          Age                                0.289211
# AppointmentID                     SMS_received                       0.255334
# SMS_received                      AppointmentID                      0.255334
# No-show                           DaysBetween                        0.186853
# DaysBetween                       No-show                            0.186853
# No-show                           AppointmentID                      0.161495
# AppointmentID                     No-show                            0.161495
# DaysBetween                       Neighbourhood_JARDIM CAMBURI       0.154488
# Neighbourhood_JARDIM CAMBURI      DaysBetween                        0.154488
# No-show                           SMS_received                       0.127054
# SMS_received                      No-show                            0.127054
# AppointmentID                     Neighbourhood_JARDIM CAMBURI       0.116876
# Neighbourhood_JARDIM CAMBURI      AppointmentID                      0.116876
# Gender                            Scholarship                        0.115467
# Scholarship                       Gender                             0.115467
# Gender                            Alcoholism                         0.107573
# Alcoholism                        Gender                             0.107573
# Neighbourhood_MARIA ORTIZ         Hipertension                       0.104910
# Hipertension                      Neighbourhood_MARIA ORTIZ          0.104910
# Age                               Gender                             0.103527
# Gender                            Age                                0.103527
# Alcoholism                        Age                                0.098092
# Age                               Alcoholism                         0.098092
# Scholarship                       Age                                0.094128
# Age                               Scholarship                        0.094128
# Hipertension                      Neighbourhood_JARDIM CAMBURI       0.091644
# Neighbourhood_JARDIM CAMBURI      Hipertension                       0.091644
# Neighbourhood_SANTA MARTHA        Alcoholism                         0.086400
# Alcoholism                        Neighbourhood_SANTA MARTHA         0.086400
# Hipertension                      Alcoholism                         0.082532
# Alcoholism                        Hipertension                       0.082532
# Handcap                           Hipertension                       0.081924
# Hipertension                      Handcap                            0.081924
# Age                               Neighbourhood_JARDIM CAMBURI       0.080211
# Neighbourhood_JARDIM CAMBURI      Age                                0.080211
# Scholarship                       Neighbourhood_ILHA DO PRÍNCIPE     0.079698
# Neighbourhood_ILHA DO PRÍNCIPE    Scholarship                        0.079698
# Age                               Handcap                            0.076306
# Handcap                           Age                                0.076306
# Neighbourhood_JARDIM CAMBURI      Scholarship                        0.072019
# Scholarship                       Neighbourhood_JARDIM CAMBURI       0.072019
#                                   Neighbourhood_SÃO BENEDITO         0.071603
# Neighbourhood_SÃO BENEDITO        Scholarship                        0.071603
# Age                               Neighbourhood_JARDIM DA PENHA      0.065131
# Neighbourhood_JARDIM DA PENHA     Age                                0.065131
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_MARIA ORTIZ          0.064419
# Neighbourhood_MARIA ORTIZ         Neighbourhood_JARDIM CAMBURI       0.064419
# Neighbourhood_JARDIM DA PENHA     Scholarship                        0.062571
# Scholarship                       Neighbourhood_JARDIM DA PENHA      0.062571
#                                   Neighbourhood_MARIA ORTIZ          0.062164
# Neighbourhood_MARIA ORTIZ         Scholarship                        0.062164
# Neighbourhood_JABOUR              Hipertension                       0.060843
# Hipertension                      Neighbourhood_JABOUR               0.060843
# No-show                           Age                                0.058533
# Age                               No-show                            0.058533
# Neighbourhood_ILHA DE SANTA MARIA Hipertension                       0.057933
# Hipertension                      Neighbourhood_ILHA DE SANTA MARIA  0.057933
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_RESISTÊNCIA          0.056206
# Neighbourhood_RESISTÊNCIA         Neighbourhood_JARDIM CAMBURI       0.056206
# DaysBetween                       Neighbourhood_MARUÍPE              0.055131
# Neighbourhood_MARUÍPE             DaysBetween                        0.055131
# Diabetes                          Neighbourhood_MARIA ORTIZ          0.054678
# Neighbourhood_MARIA ORTIZ         Diabetes                           0.054678
# Hipertension                      Gender                             0.054617
# Gender                            Hipertension                       0.054617
# Handcap                           Diabetes                           0.054423
# Diabetes                          Handcap                            0.054423
# Neighbourhood_JESUS DE NAZARETH   Age                                0.053772
# Age                               Neighbourhood_JESUS DE NAZARETH    0.053772
# Neighbourhood_JARDIM DA PENHA     Neighbourhood_JARDIM CAMBURI       0.053169
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_JARDIM DA PENHA      0.053169
# Neighbourhood_PRAIA DO CANTO      Age                                0.053125
# Age                               Neighbourhood_PRAIA DO CANTO       0.053125
# Alcoholism                        Neighbourhood_ESTRELINHA           0.052696
# Neighbourhood_ESTRELINHA          Alcoholism                         0.052696
# DaysBetween                       Neighbourhood_NOVA PALESTINA       0.051954
# Neighbourhood_NOVA PALESTINA      DaysBetween                        0.051954
# DaysBetween                       Neighbourhood_SANTA CECÍLIA        0.051389
# Neighbourhood_SANTA CECÍLIA       DaysBetween                        0.051389
# Neighbourhood_ITARARÉ             Neighbourhood_JARDIM CAMBURI       0.049734
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_ITARARÉ              0.049734
# Neighbourhood_CENTRO              Neighbourhood_JARDIM CAMBURI       0.048618
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_CENTRO               0.048618
# Scholarship                       Neighbourhood_GURIGICA             0.048283
# Neighbourhood_GURIGICA            Scholarship                        0.048283
# Neighbourhood_SÃO PEDRO           DaysBetween                        0.048257
# DaysBetween                       Neighbourhood_SÃO PEDRO            0.048257
# Neighbourhood_MARIA ORTIZ         Neighbourhood_RESISTÊNCIA          0.048206
# Neighbourhood_RESISTÊNCIA         Neighbourhood_MARIA ORTIZ          0.048206
# Neighbourhood_JARDIM CAMBURI      Alcoholism                         0.047630
# Alcoholism                        Neighbourhood_JARDIM CAMBURI       0.047630
# Neighbourhood_SANTA MARTHA        Neighbourhood_JARDIM CAMBURI       0.047053
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_SANTA MARTHA         0.047053
# Neighbourhood_TABUAZEIRO          Neighbourhood_JARDIM CAMBURI       0.046614
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_TABUAZEIRO           0.046614
# SMS_received                      Gender                             0.046360
# Gender                            SMS_received                       0.046360
# DaysBetween                       Neighbourhood_MARIA ORTIZ          0.046157
# Neighbourhood_MARIA ORTIZ         DaysBetween                        0.046157
# Neighbourhood_JARDIM DA PENHA     Neighbourhood_MARIA ORTIZ          0.045601
# Neighbourhood_MARIA ORTIZ         Neighbourhood_JARDIM DA PENHA      0.045601
# Neighbourhood_DA PENHA            Alcoholism                         0.044675
# Alcoholism                        Neighbourhood_DA PENHA             0.044675
# Neighbourhood_BONFIM              Neighbourhood_JARDIM CAMBURI       0.044466
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_BONFIM               0.044466
#                                   Neighbourhood_JESUS DE NAZARETH    0.044198
# Neighbourhood_JESUS DE NAZARETH   Neighbourhood_JARDIM CAMBURI       0.044198
# Neighbourhood_SANTO ANTÔNIO       Neighbourhood_JARDIM CAMBURI       0.043722
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_SANTO ANTÔNIO        0.043722
# AppointmentID                     Neighbourhood_MARIA ORTIZ          0.043259
# Neighbourhood_MARIA ORTIZ         AppointmentID                      0.043259
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_CARATOÍRA            0.042678
# Neighbourhood_CARATOÍRA           Neighbourhood_JARDIM CAMBURI       0.042678
# Neighbourhood_ITARARÉ             Neighbourhood_MARIA ORTIZ          0.042655
# Neighbourhood_MARIA ORTIZ         Neighbourhood_ITARARÉ              0.042655
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_JABOUR               0.042600
# Neighbourhood_JABOUR              Neighbourhood_JARDIM CAMBURI       0.042600
# Neighbourhood_CENTRO              Age                                0.042429
# Age                               Neighbourhood_CENTRO               0.042429
# Neighbourhood_SÃO BENEDITO        Age                                0.042413
# Age                               Neighbourhood_SÃO BENEDITO         0.042413
# DaysBetween                       Neighbourhood_ILHA DO PRÍNCIPE     0.042205
# Neighbourhood_ILHA DO PRÍNCIPE    DaysBetween                        0.042205
# Age                               Neighbourhood_GURIGICA             0.042105
# Neighbourhood_GURIGICA            Age                                0.042105
# Neighbourhood_SANTO ANDRÉ         Neighbourhood_JARDIM CAMBURI       0.041815
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_SANTO ANDRÉ          0.041815
# Neighbourhood_MARIA ORTIZ         Neighbourhood_CENTRO               0.041698
# Neighbourhood_CENTRO              Neighbourhood_MARIA ORTIZ          0.041698
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_SÃO PEDRO            0.041383
# Neighbourhood_SÃO PEDRO           Neighbourhood_JARDIM CAMBURI       0.041383
# Neighbourhood_MARIA ORTIZ         Alcoholism                         0.041315
# Alcoholism                        Neighbourhood_MARIA ORTIZ          0.041315
# Neighbourhood_MARUÍPE             AppointmentID                      0.041165
# AppointmentID                     Neighbourhood_MARUÍPE              0.041165
# Neighbourhood_NOVA PALESTINA      AppointmentID                      0.040510
# AppointmentID                     Neighbourhood_NOVA PALESTINA       0.040510
# Neighbourhood_SANTA MARTHA        Neighbourhood_MARIA ORTIZ          0.040356
# Neighbourhood_MARIA ORTIZ         Neighbourhood_SANTA MARTHA         0.040356
# Neighbourhood_CARATOÍRA           Scholarship                        0.040341
# Scholarship                       Neighbourhood_CARATOÍRA            0.040341
# Neighbourhood_TABUAZEIRO          Scholarship                        0.040146
# Scholarship                       Neighbourhood_TABUAZEIRO           0.040146
# DaysBetween                       Alcoholism                         0.039989
# Alcoholism                        DaysBetween                        0.039989
# Neighbourhood_MARIA ORTIZ         Neighbourhood_TABUAZEIRO           0.039979
# Neighbourhood_TABUAZEIRO          Neighbourhood_MARIA ORTIZ          0.039979
# Neighbourhood_JARDIM CAMBURI      Diabetes                           0.039869
# Diabetes                          Neighbourhood_JARDIM CAMBURI       0.039869
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_ILHA DO PRÍNCIPE     0.039850
# Neighbourhood_ILHA DO PRÍNCIPE    Neighbourhood_JARDIM CAMBURI       0.039850
# Neighbourhood_JARDIM DA PENHA     Neighbourhood_RESISTÊNCIA          0.039788
# Neighbourhood_RESISTÊNCIA         Neighbourhood_JARDIM DA PENHA      0.039788
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_NOVA PALESTINA       0.039660
# Neighbourhood_NOVA PALESTINA      Neighbourhood_JARDIM CAMBURI       0.039660
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_ROMÃO                0.039577
# Neighbourhood_ROMÃO               Neighbourhood_JARDIM CAMBURI       0.039577
# Neighbourhood_ANDORINHAS          Neighbourhood_JARDIM CAMBURI       0.039541
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_ANDORINHAS           0.039541
# DaysBetween                       Neighbourhood_FONTE GRANDE         0.039519
# Neighbourhood_FONTE GRANDE        DaysBetween                        0.039519
# Neighbourhood_DA PENHA            Neighbourhood_JARDIM CAMBURI       0.038833
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_DA PENHA             0.038833
# Neighbourhood_CRUZAMENTO          Alcoholism                         0.038300
# Alcoholism                        Neighbourhood_CRUZAMENTO           0.038300
# Handcap                           Neighbourhood_MATA DA PRAIA        0.038264
# Neighbourhood_MATA DA PRAIA       Handcap                            0.038264
# Neighbourhood_RESISTÊNCIA         Age                                0.038195
# Age                               Neighbourhood_RESISTÊNCIA          0.038195
# Neighbourhood_MARIA ORTIZ         Neighbourhood_BONFIM               0.038137
# Neighbourhood_BONFIM              Neighbourhood_MARIA ORTIZ          0.038137
# Hipertension                      Neighbourhood_MONTE BELO           0.037976
# Neighbourhood_MONTE BELO          Hipertension                       0.037976
# Neighbourhood_MARIA ORTIZ         Neighbourhood_JESUS DE NAZARETH    0.037907
# Neighbourhood_JESUS DE NAZARETH   Neighbourhood_MARIA ORTIZ          0.037907
# Age                               Neighbourhood_PARQUE MOSCOSO       0.037808
# Neighbourhood_PARQUE MOSCOSO      Age                                0.037808
# Neighbourhood_MARIA ORTIZ         Neighbourhood_SANTO ANTÔNIO        0.037499
# Neighbourhood_SANTO ANTÔNIO       Neighbourhood_MARIA ORTIZ          0.037499
# Neighbourhood_GURIGICA            Neighbourhood_JARDIM CAMBURI       0.037404
# Neighbourhood_JARDIM CAMBURI      Neighbourhood_GURIGICA             0.037404
# Neighbourhood_ITARARÉ             Neighbourhood_RESISTÊNCIA          0.037217
# Neighbourhood_RESISTÊNCIA         Neighbourhood_ITARARÉ              0.037217
# AppointmentID                     Neighbourhood_ILHA DO PRÍNCIPE     0.037141
# Neighbourhood_ILHA DO PRÍNCIPE    AppointmentID                      0.037141
# Neighbourhood_ILHA DE SANTA MARIA Scholarship                        0.036900
# Scholarship                       Neighbourhood_ILHA DE SANTA MARIA  0.036900
# SMS_received                      Neighbourhood_CARATOÍRA            0.036672
# Neighbourhood_CARATOÍRA           SMS_received                       0.036672
# DaysBetween                       Neighbourhood_DA PENHA             0.036662
# Neighbourhood_DA PENHA            DaysBetween                        0.036662

# %% [markdown]
# ## correlaction gander vs target

# %%
sns.countplot(x="Gender", hue="No-show", data=train_prep)

# %% [markdown]
#  caterogies 0- woman
#             1- men
#             0- No
#             1- Yes

# %%
# how many woman and how many man appear 
train_prep.Gender[train_prep['No-show']==0].value_counts()/train_prep.Gender.value_counts()
# Out:
# 0    0.795358
# 1    0.798895
# Name: Gender, dtype: float64

# %%
train_prep.Gender[train_prep['No-show']==0].value_counts()
# Out:
# 0    42865
# 1    22993
# Name: Gender, dtype: int64

# %%
# how many woman and how many man didn't appear 
train_prep.Gender[train_prep['No-show']==1].value_counts()/train_prep.Gender.value_counts()
# Out:
# 0    0.204642
# 1    0.201105
# Name: Gender, dtype: float64

# %%
train_prep.groupby('No-show')['Gender'].value_counts()
# Out:
# No-show  Gender
# 0        0         42865
#          1         22993
# 1        0         11029
#          1          5788
# Name: Gender, dtype: int64

# %%
# matthews corrcoef is good for binary correlaction
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(train.Gender,train['No-show'])

# %% [markdown]
# correlation diffrence time sheduled and appoitment vs target

# %% [markdown]
# ## correlation diffrence time sheduled and appoitment vs target & vs gender

# %% [markdown]
# calculate days between scheduled and appoitment.
# - check if we have collelation between days and target
# - wenn the woman and the men do appoitment

# %%
train_prep.groupby('DaysBetween')['Gender'].value_counts()
# we see that we have some data with -6 days what means that we should drop this data
# Out:
# DaysBetween  Gender
# -6           0             1
# -1           0             2
#              1             1
#  0           0         17759
#              1         10946
#  1           0          2538
#              1          1342
#  2           0          3420
#              1          1666
#  3           0          1341
#              1           699
#  4           0          2685
#              1          1293
#  5           0          1653
#              1           811
#  6           0          2040
#              1           984
#  7           0          2363
#              1          1283
#  8           0          1213
#              1           557
#  9           0           813
#              1           408
#  10          0           717
#              1           356
#  11          0           476
#              1           257
#  12          0           544
#              1           257
#  13          0           863
#              1           415
#  14          0          1460
#              1           694
#  15          0           751
#              1           343
#  16          0           576
#              1           288
#  17          0           564
#              1           285
#  18          0           511
#              1           249
#  19          0           520
#              1           261
#  20          0           581
#              1           302
#  21          0           956
#              1           448
#  22          0           599
#              1           270
#  23          0           437
#              1           180
#  24          0           314
#              1           133
#  25          0           314
#              1           173
#  26          0           384
#              1           170
#  27          0           528
#              1           214
#  28          0           862
#              1           391
#  29          0           570
#              1           263
#  30          0           341
#              1           203
#  31          0           316
#              1           191
#  32          0           289
#              1           154
#  33          0           317
#              1           182
#  34          0           389
#              1           219
#  35          0           476
#              1           244
#  36          0           253
#              1           139
#  37          0           146
#              1           103
#  38          0           101
#              1            64
#  39          0            87
#              1            51
#  40          0           114
#              1            74
#  41          0           164
#              1            95
#  42          0           193
#              1           115
#  43          0           135
#              1            67
#  44          0            91
#              1            34
#  45          0            76
#              1            33
#  46          0            64
#              1            20
#  47          0            70
#              1            19
#  48          0            56
#              1            21
#  49          0           112
#              1            48
#  50          0           106
#              1            37
#  51          0            51
#              1            22
#  52          0            54
#              1            20
#  53          0            48
#              1            21
#  54          0            34
#              1            18
#  55          1            41
#              0            40
#  56          0           109
#              1            44
#  57          0            48
#              1            21
#  58          0            53
#              1            32
#  59          0            45
#              1            27
#  60          0            42
#              1            19
#  61          0            76
#              1            28
#  62          0           114
#              1            25
#  63          0           105
#              1            58
#  64          0            31
#              1            23
#  65          0            48
#              1            26
#  66          0            83
#              1            31
#  67          0            35
#              1            15
#  68          0            38
#              1            18
#  69          0            57
#              1            19
#  70          0            55
#              1            25
#  71          0            23
#              1            15
#  72          0            28
#              1            14
#  73          0            25
#              1             3
#  74          0            20
#              1            13
#  75          0            37
#              1            15
#  76          0            39
#              1             9
#  77          0            28
#              1            12
#  78          0            14
#              1            13
#  79          0            19
#              1             1
#  80          0            11
#              1             2
#  81          0             5
#              1             2
#  83          0             3
#              1             2
#  84          0            29
#              1            11
#  85          0            16
#              1             8
#  86          0             2
#              1             2
#  87          0            10
#              1             5
#  88          0             9
#              1             4
#  89          0             8
#              1             2
#  90          0            31
#              1            18
#  91          0            43
#              1             3
#  92          0             1
#              1             1
#  93          0             1
#              1             1
#  94          0             1
#              1             1
#  95          0             1
#              1             1
#  96          0             3
#              1             1
#  97          0             1
#              1             1
#  98          0             4
#  101         0             1
#  102         0             2
#              1             1
#  103         0             1
#              1             1
#  104         0             4
#              1             1
#  105         0             2
#              1             2
#  107         0             2
#  108         1             3
#              0             1
#  109         0             3
#              1             1
#  110         0             1
#              1             1
#  111         1             2
#              0             1
#  112         0             4
#              1             1
#  115         1             1
#  117         0             1
#  119         0             2
#              1             1
#  122         1             2
#  123         0             1
#  127         1             1
#  132         1             1
#  133         0             8
#              1             1
#  139         1             1
#  142         0             2
#              1             1
#  146         0             1
#  151         1             1
#  155         0             5
#              1             3
#  162         0             4
#              1             4
#  169         0             4
#              1             1
#  176         0             9
#              1             2
#  179         0             6
#              1             3
# Name: Gender, dtype: int64

# %%
a = train_prep.groupby('DaysBetween')['Gender'].value_counts()

a.unstack(level=0)#.plot(kind='bar', subplots=False)
# Out:
# DaysBetween  -6    -1        0       1       2       3       4       5    \
# Gender
# 0             1.0   2.0  17759.0  2538.0  3420.0  1341.0  2685.0  1653.0
# 1             NaN   1.0  10946.0  1342.0  1666.0   699.0  1293.0   811.0
#
# DaysBetween     6       7    ...   133   139   142   146   151   155   162  \
# Gender                       ...
# 0            2040.0  2363.0  ...   8.0   NaN   2.0   1.0   NaN   5.0   4.0
# 1             984.0  1283.0  ...   1.0   1.0   1.0   NaN   1.0   3.0   4.0
#
# DaysBetween   169   176   179
# Gender
# 0             4.0   9.0   6.0
# 1             1.0   2.0   3.0
#
# [2 rows x 128 columns]

# %%
cut_bins = [-0.001, 7, 14, 28, 84,168]
train_prep['days in week range']=pd.cut(train_prep['DaysBetween'],bins=cut_bins, labels = [1,2,4,12,24])

# %%
#without normalization
sns.countplot(x='days in week range',hue='Gender',data=train_prep)

# %%
aft_cut = train_prep.groupby(train_prep['days in week range'])['Gender'].value_counts()
aft_cut
aft_cut = aft_cut.groupby(level=1).apply(lambda x:x / float(x.sum()))
aft_cut 

#aft_cut.unstack().plot(kind='bar')
# Out:
# days in week range  Gender
# 1                   0         0.627395
#                     1         0.661152
# 2                   0         0.112971
#                     1         0.102315
# 4                   0         0.146588
#                     1         0.128832
# 12                  0         0.109760
#                     1         0.104991
# 24                  0         0.003286
#                     1         0.002711
# Name: Gender, dtype: float64

# %%
#normalization for woman
xy = train_prep.groupby(train['ScheduledDay'].apply(lambda x :x.weekday))['Gender'].value_counts()
xy
state_pcts = xy.groupby(level=1).apply(lambda x:x / float(x.sum()))
state_pcts
state_pcts.unstack().plot(kind='bar')

# %%
sns.countplot(x=train_prep['ScheduledDay'].apply(lambda x :x.month),hue='Gender',data=train_prep)

# %%
zz = train_prep.groupby(train_prep['ScheduledDay'].apply(lambda x:x.month))['Gender'].value_counts()

zz.groupby(level=1).apply(lambda x: x/float(x.sum())).unstack().plot(kind='bar')

# %% [markdown]
# ## Neighbourhood

# %%
train.Neighbourhood.value_counts()

# %%
zz = train.groupby(train['Neighbourhood'])['No-show'].value_counts()
zz
zz = zz.groupby(level=0).apply(lambda x: x/float(x.sum()))#.unstack().plot(kind='bar')##
zz
zz.loc[:,1].sort_values(ascending=False).head(40).plot(kind='bar')

# %% [markdown]
# ## Age

# %%
cut_bins = [-2, 20, 30, 40, 50,60,70,80,90,100,120]
train['age_after_cut']=pd.cut(train['Age'],bins=cut_bins, labels = [10, 20, 30, 40, 50,60,70,80,90,120])
train['age_after_cut'].value_counts().plot(kind='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#without normalization
ag = train.groupby(train['age_after_cut'])['Gender'].value_counts()
ag
#ag.unstack().plot(kind='bar')
#with normalization
ag.groupby(level=1).apply(lambda x: x/float(x.sum())).unstack().plot(kind='bar')

# %%
ag.groupby(level=1).apply(lambda x: x/float(x.sum()))

# %% [markdown]
# ## the older the people, the more sick they are?

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age', y ='Diabetes',hue='Gender',data=train,err_style='band')
